# %%
#1. Create a 3x3x3 array with random values.
import numpy as np
array = np.random.random((3, 3, 3))
array
# Out:
# array([[[0.29719841, 0.23826705, 0.39010052],
#         [0.26554064, 0.87074801, 0.62241273],
#         [0.53629684, 0.9186778 , 0.55831052]],
#
#        [[0.84644392, 0.29968786, 0.81315815],
#         [0.40967574, 0.26053118, 0.79641296],
#         [0.62855503, 0.52413264, 0.27191744]],
#
#        [[0.65691401, 0.562913  , 0.61069375],
#         [0.28133682, 0.66408599, 0.09876205],
#         [0.92735411, 0.93042675, 0.28428059]]])

# %%
#2. 
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.head(10)
#Filter Passengers Who Paid More than $100: Create a DataFrame with passengers who paid a fare greater than $100.
new_titanic = titanic[titanic['fare'] > 100]
new_titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 27          0       1    male  19.00      3      2  263.0000        S  First
# 31          1       1  female    NaN      1      0  146.5208        C  First
# 88          1       1  female  23.00      3      2  263.0000        S  First
# 118         0       1    male  24.00      0      1  247.5208        C  First
# 195         1       1  female  58.00      0      0  146.5208        C  First
# 215         1       1  female  31.00      1      0  113.2750        C  First
# 258         1       1  female  35.00      0      0  512.3292        C  First
# 268         1       1  female  58.00      0      1  153.4625        S  First
# 269         1       1  female  35.00      0      0  135.6333        S  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 299         1       1  female  50.00      0      1  247.5208        C  First
# ...

# %%
#3. Use this url : https://openweathermap.org/
#Use the requests library to fetch weather data for a specific city(ex. your hometown: Tashkent) and print relevant information (temperature, humidity, etc.).

import requests

API_KEY = '1f17da702228a2704dfbe2902a1dfd6d' 
city = 'Tashkent'
url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

response = requests.get(url)
data = response.json()
city = data['name']
weather = data['weather'][0]['main']
temp = data['main']['temp']
pressure = data['main']['pressure']
humidity = data['main']['humidity']
wind = data['wind']['speed']
clouds = data['clouds']['all']


print(f'In {city}, the temperature is {temp}℃, {weather}. \n\nPressure: {pressure}.\nHumidity: {humidity}.\nWind speed: {wind}\n\n    with {clouds} clouds')
# Out:
# In Tashkent, the temperature is 27.91℃, Clear.
#
# Pressure: 1008.
# Humidity: 23.
# Wind speed: 1.83
#
#     with 0 clouds

# %%
#4. 
import pandas as pd

data2 = {
    'Date': pd.date_range(start='2023-01-01', periods=10),
    'Product_A': [120, 150, 130, 110, 140, 160, 135, 125, 145, 155],
    'Product_B': [90, 110, 100, 80, 95, 105, 98, 88, 102, 112],
    'Product_C': [75, 80, 85, 70, 88, 92, 78, 82, 87, 90]
}

df2 = pd.DataFrame(data2)


#Calculate the percentage change in sales for each product from the previous day.


df2['A_Change'] = df2['Product_A'].pct_change() * 100
df2['B_Change'] = df2['Product_B'].pct_change() * 100
df2['C_Change'] = df2['Product_C'].pct_change() * 100

df2['A_Change'] = df2['A_Change'].round(2)
df2['B_Change'] = df2['B_Change'].round(2)
df2['C_Change'] = df2['C_Change'].round(2)

print(df2)
# Out:
#         Date  Product_A  Product_B  Product_C  A_Change  B_Change  C_Change
# 0 2023-01-01        120         90         75       NaN       NaN       NaN
# 1 2023-01-02        150        110         80     25.00     22.22      6.67
# 2 2023-01-03        130        100         85    -13.33     -9.09      6.25
# 3 2023-01-04        110         80         70    -15.38    -20.00    -17.65
# 4 2023-01-05        140         95         88     27.27     18.75     25.71
# 5 2023-01-06        160        105         92     14.29     10.53      4.55
# 6 2023-01-07        135         98         78    -15.62     -6.67    -15.22
# 7 2023-01-08        125         88         82     -7.41    -10.20      5.13
# 8 2023-01-09        145        102         87     16.00     15.91      6.10
# 9 2023-01-10        155        112         90      6.90      9.80      3.45

# %%
#5. 
import pandas as pd
import matplotlib.pyplot as plt

data4 = {
    'Order_ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Customer_ID': [201, 202, 203, 204, 205, 206, 207, 208, 209, 210],
    'Product': ['A', 'B', 'A', 'C', 'B', 'C', 'A', 'C', 'B', 'A'],
    'Quantity': [2, 3, 1, 4, 2, 3, 2, 5, 1, 3],
    'Total_Price': [120, 180, 60, 240, 160, 270, 140, 300, 90, 180]
}

df4 = pd.DataFrame(data4)

# Exercise 1: Calculate the total revenue from all orders.
# Exercise 2: Find the most ordered product.
# Exercise 3: Calculate the average quantity of products ordered.
# Exercise 4: Plot a pie chart to visualize the distribution of sales across different products.

#Exercise 1
df4['Revenue'] = df4['Quantity'] * df4['Total_Price']
Total = sum(df4['Revenue'])
print(f'Total: {Total}')



#Exercise 2
Most_ordered = df4['Product'].mode()[0]
print(f'Most_ordered: {Most_ordered}')

#Exercise 3
Average = df4['Quantity'].mean()
print(f'Average: {Average}')


#Exercise 4
sales_dist = df4.groupby('Product')['Total_Price'].sum()
sales_dist.plot.pie(autopct='%.1f%%')
plt.title("Sales Distribution by Product")
plt.ylabel("")  
plt.show()
# Out:
# Total: 5340
# Most_ordered: A
# Average: 2.6
