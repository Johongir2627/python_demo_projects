# %%
import pandas as pd
df = pd.DataFrame([[1,2,3], [4,5,6], [7,8,9]])

# %%
print(df)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.head()
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
import pandas as pd
df = pd.DataFrame([[1,2,3], [4,5,6], [7,8,9]], columns=['A', 'B', 'C'])

# %%
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.head(1)
# Out:
#    A  B  C
# 0  1  2  3

# %%
df.tail(2)
# Out:
#    A  B  C
# 1  4  5  6
# 2  7  8  9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.index.tolist()
# Out:
# [0, 1, 2]

# %%
import pandas as pd
df = pd.DataFrame([[1,2,3], [4,5,6], [7,8,9]], columns=['A', 'B', 'C'], index=['x', 'y', 'z'])

# %%
df
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df.index.tolist()
# Out:
# ['x', 'y', 'z']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].nunique()
# Out:
# 3

# %%
df['A'].unique()
# Out:
# array([1, 4, 7])

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
food = pd.read_csv('food_prices.csv')

# %%
food.head()
# Out:
#      item store  price  Date
# 0    pear     A   0.99  2017
# 1    pear     B   1.99  2017
# 2   peach     A   2.99  2017
# 3   peach     B   3.49  2017
# 4  banana     A   0.39  2017

# %%
food.sample(5) # random 5
# Out:
#      item store  price  Date
# 8   steak     B   4.99  2015
# 4  banana     A   0.39  2017
# 0    pear     A   0.99  2017
# 1    pear     B   1.99  2017
# 3   peach     B   3.49  2017

# %%
food.sample(5, random_state=1)
# Out:
#     item store  price  Date
# 8  steak     B   4.99  2015
# 2  peach     A   2.99  2017
# 6  steak     A   5.99  2017
# 7  steak     B   6.99  2017
# 1   pear     B   1.99  2017

# %%
food.loc(0)

# %%
food.loc[0]
# Out:
# item     pear
# store       A
# price    0.99
# Date     2017
# Name: 0, dtype: object

# %%
food.loc[[1, 3, 5]]
# Out:
#      item store  price  Date
# 1    pear     B   1.99  2017
# 3   peach     B   3.49  2017
# 5  banana     B   0.49  2017

# %%
food.loc[2:5]
# Out:
#      item store  price  Date
# 2   peach     A   2.99  2017
# 3   peach     B   3.49  2017
# 4  banana     A   0.39  2017
# 5  banana     B   0.49  2017

# %%
food.loc[2:5, ['store']]
# Out:
#   store
# 2     A
# 3     B
# 4     A
# 5     B

# %%
food.loc[2:5, ['store', 'price']]
# Out:
#   store  price
# 2     A   2.99
# 3     B   3.49
# 4     A   0.39
# 5     B   0.49

# %%
food.loc[:, ['store', 'price']]
# Out:
#   store  price
# 0     A   0.99
# 1     B   1.99
# 2     A   2.99
# 3     B   3.49
# 4     A   0.39
# 5     B   0.49
# 6     A   5.99
# 7     B   6.99
# 8     B   4.99

# %%
food.iloc[[1, 2, 5], [1, 2]]
# Out:
#   store  price
# 1     B   1.99
# 2     A   2.99
# 5     B   0.49

# %%
food.index=food['item']

# %%
food
# Out:
#           item store  price  Date
# item
# pear      pear     A   0.99  2017
# pear      pear     B   1.99  2017
# peach    peach     A   2.99  2017
# peach    peach     B   3.49  2017
# banana  banana     A   0.39  2017
# banana  banana     B   0.49  2017
# steak    steak     A   5.99  2017
# steak    steak     B   6.99  2017
# steak    steak     B   4.99  2015

# %%
food.loc[['pear', 'banana'], 'store']
# Out:
# item
# pear      A
# pear      B
# banana    A
# banana    B
# Name: store, dtype: object

# %%
food
# Out:
#           item store  price  Date
# item
# pear      pear     A   0.99  2017
# pear      pear     B   1.99  2017
# peach    peach     A   2.99  2017
# peach    peach     B   3.49  2017
# banana  banana     A   0.39  2017
# banana  banana     B   0.49  2017
# steak    steak     A   5.99  2017
# steak    steak     B   6.99  2017
# steak    steak     B   4.99  2015

# %%
food.loc['banana', 'store'] = 'C'

# %%
food
# Out:
#           item store  price  Date
# item
# pear      pear     A   0.99  2017
# pear      pear     B   1.99  2017
# peach    peach     A   2.99  2017
# peach    peach     B   3.49  2017
# banana  banana     C   0.39  2017
# banana  banana     C   0.49  2017
# steak    steak     A   5.99  2017
# steak    steak     B   6.99  2017
# steak    steak     B   4.99  2015

# %%
food.iat[0,0]
# Out:
# 'pear'

# %%
food.sort_values('price')
# Out:
#           item store  price  Date
# item
# banana  banana     C   0.39  2017
# banana  banana     C   0.49  2017
# pear      pear     A   0.99  2017
# pear      pear     B   1.99  2017
# peach    peach     A   2.99  2017
# peach    peach     B   3.49  2017
# steak    steak     B   4.99  2015
# steak    steak     A   5.99  2017
# steak    steak     B   6.99  2017

# %%
food.sort_values('price', ascending=True)
# Out:
#           item store  price  Date
# item
# banana  banana     C   0.39  2017
# banana  banana     C   0.49  2017
# pear      pear     A   0.99  2017
# pear      pear     B   1.99  2017
# peach    peach     A   2.99  2017
# peach    peach     B   3.49  2017
# steak    steak     B   4.99  2015
# steak    steak     A   5.99  2017
# steak    steak     B   6.99  2017

# %%
food.sort_values(['price', 'store'], ascending=False)
# Out:
#           item store  price  Date
# item
# steak    steak     B   6.99  2017
# steak    steak     A   5.99  2017
# steak    steak     B   4.99  2015
# peach    peach     B   3.49  2017
# peach    peach     A   2.99  2017
# pear      pear     B   1.99  2017
# pear      pear     A   0.99  2017
# banana  banana     C   0.49  2017
# banana  banana     C   0.39  2017

# %%
food.sort_values(['price', 'store'], ascending=[0, 1])
# Out:
#           item store  price  Date
# item
# steak    steak     B   6.99  2017
# steak    steak     A   5.99  2017
# steak    steak     B   4.99  2015
# peach    peach     B   3.49  2017
# peach    peach     A   2.99  2017
# pear      pear     B   1.99  2017
# pear      pear     A   0.99  2017
# banana  banana     C   0.49  2017
# banana  banana     C   0.39  2017

# %%
for index, row in food.iterrows():
    print(index)
    print(row)
    print('\n\n')
# Out:
# pear
# item     pear
# store       A
# price    0.99
# Date     2017
# Name: pear, dtype: object
#
#
#
# pear
# item     pear
# store       B
# price    1.99
# Date     2017
# Name: pear, dtype: object
#
#
#
# peach
# item     peach
# store        A
# price     2.99
# Date      2017
# Name: peach, dtype: object
#
#
#
# peach
# item     peach
# store        B
# price     3.49
# Date      2017
# Name: peach, dtype: object
#
#
#
# banana
# item     banana
# store         C
# price      0.39
# Date       2017
# Name: banana, dtype: object
#
#
#
# banana
# item     banana
# store         C
# price      0.49
# Date       2017
# Name: banana, dtype: object
#
#
#
# steak
# item     steak
# store        A
# price     5.99
# Date      2017
# Name: steak, dtype: object
#
#
#
# steak
# item     steak
# store        B
# price     6.99
# Date      2017
# Name: steak, dtype: object
#
#
#
# steak
# item     steak
# store        B
# price     4.99
# Date      2015
# Name: steak, dtype: object

# %%
for index, row in food.iterrows():
    print(index)
    print(row['price'])
    print('\n\n')
# Out:
# pear
# 0.99
#
#
#
# pear
# 1.99
#
#
#
# peach
# 2.99
#
#
#
# peach
# 3.49
#
#
#
# banana
# 0.39
#
#
#
# banana
# 0.49
#
#
#
# steak
# 5.99
#
#
#
# steak
# 6.99
#
#
#
# steak
# 4.99

# %%
food.loc[food['price']>0.1]
# Out:
#           item store  price  Date
# item
# pear      pear     A   0.99  2017
# pear      pear     B   1.99  2017
# peach    peach     A   2.99  2017
# peach    peach     B   3.49  2017
# banana  banana     C   0.39  2017
# banana  banana     C   0.49  2017
# steak    steak     A   5.99  2017
# steak    steak     B   6.99  2017
# steak    steak     B   4.99  2015

# %%
food.loc[food['price']>0.1, ['item', 'store']]
# Out:
#           item store
# item
# pear      pear     A
# pear      pear     B
# peach    peach     A
# peach    peach     B
# banana  banana     C
# banana  banana     C
# steak    steak     A
# steak    steak     B
# steak    steak     B

# %%
food.loc[food['price']>0.1][['item', 'store']]
# Out:
#           item store
# item
# pear      pear     A
# pear      pear     B
# peach    peach     A
# peach    peach     B
# banana  banana     C
# banana  banana     C
# steak    steak     A
# steak    steak     B
# steak    steak     B

# %%
food[food['price']>0.1]
# Out:
#           item store  price  Date
# item
# pear      pear     A   0.99  2017
# pear      pear     B   1.99  2017
# peach    peach     A   2.99  2017
# peach    peach     B   3.49  2017
# banana  banana     C   0.39  2017
# banana  banana     C   0.49  2017
# steak    steak     A   5.99  2017
# steak    steak     B   6.99  2017
# steak    steak     B   4.99  2015

# %%
food[(food['price']>0.1) & (food['store'] == 'A')]
# Out:
#         item store  price  Date
# item
# pear    pear     A   0.99  2017
# peach  peach     A   2.99  2017
# steak  steak     A   5.99  2017

# %%
food[food['item'].str.contains('pea')]
# Out:
#         item store  price  Date
# item
# pear    pear     A   0.99  2017
# pear    pear     B   1.99  2017
# peach  peach     A   2.99  2017
# peach  peach     B   3.49  2017

# %%
food[food['item'].str.contains('Pea', case = False)]
# Out:
#         item store  price  Date
# item
# pear    pear     A   0.99  2017
# pear    pear     B   1.99  2017
# peach  peach     A   2.99  2017
# peach  peach     B   3.49  2017

# %%
food[food['item'].str.contains('Pea|ba', case = False)]
# Out:
#           item store  price  Date
# item
# pear      pear     A   0.99  2017
# pear      pear     B   1.99  2017
# peach    peach     A   2.99  2017
# peach    peach     B   3.49  2017
# banana  banana     C   0.39  2017
# banana  banana     C   0.49  2017

# %%
food[food['item'].str.contains('Pea|ba', case = False, regex=False)]
# Out:
# Empty DataFrame
# Columns: [item, store, price, Date]
# Index: []

# %%
food[food['item'].isin(['pear'])]
# Out:
#       item store  price  Date
# item
# pear  pear     A   0.99  2017
# pear  pear     B   1.99  2017

# %%
food.query('price== 0.99 and item == "pear"')
# Out:
#       item store  price  Date
# item
# pear  pear     A   0.99  2017

# %%
import numpy as np

# %%
food['country'] = np.where(food['item'] == 'pear', 'USA', 'Uzb')

# %%
food
# Out:
#           item store  price  Date country
# item
# pear      pear     A   0.99  2017     USA
# pear      pear     B   1.99  2017     USA
# peach    peach     A   2.99  2017     Uzb
# peach    peach     B   3.49  2017     Uzb
# banana  banana     C   0.39  2017     Uzb
# banana  banana     C   0.49  2017     Uzb
# steak    steak     A   5.99  2017     Uzb
# steak    steak     B   6.99  2017     Uzb
# steak    steak     B   4.99  2015     Uzb

# %%
food.drop(columns=['item'])
# Out:
#        store  price  Date country
# item
# pear       A   0.99  2017     USA
# pear       B   1.99  2017     USA
# peach      A   2.99  2017     Uzb
# peach      B   3.49  2017     Uzb
# banana     C   0.39  2017     Uzb
# banana     C   0.49  2017     Uzb
# steak      A   5.99  2017     Uzb
# steak      B   6.99  2017     Uzb
# steak      B   4.99  2015     Uzb

# %%
food.drop(columns=['item'], inplace=True)

# %%
food
# Out:
#      item store  price  Date
# 0    pear     A   0.99  2017
# 1    pear     B   1.99  2017
# 2   peach     A   2.99  2017
# 3   peach     B   3.49  2017
# 4  banana     A   0.39  2017
# 5  banana     B   0.49  2017
# 6   steak     A   5.99  2017
# 7   steak     B   6.99  2017
# 8   steak     B   4.99  2015

# %%
food = food.rename(columns={'block':'store'})

# %%
food
# Out:
#      item store  price  Date
# 0    pear     A   0.99  2017
# 1    pear     B   1.99  2017
# 2   peach     A   2.99  2017
# 3   peach     B   3.49  2017
# 4  banana     A   0.39  2017
# 5  banana     B   0.49  2017
# 6   steak     A   5.99  2017
# 7   steak     B   6.99  2017
# 8   steak     B   4.99  2015

# %%
food_new = food.copy()

# %%
food_new
# Out:
#      item store  price  Date
# 0    pear     A   0.99  2017
# 1    pear     B   1.99  2017
# 2   peach     A   2.99  2017
# 3   peach     B   3.49  2017
# 4  banana     A   0.39  2017
# 5  banana     B   0.49  2017
# 6   steak     A   5.99  2017
# 7   steak     B   6.99  2017
# 8   steak     B   4.99  2015
